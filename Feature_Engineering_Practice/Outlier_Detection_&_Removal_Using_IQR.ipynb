# %% [markdown]
# # Step 0: Insert libraries and Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sn
plt.style.use('ggplot')
pd.set_option('display.max_columns', 200)

# %%
df = pd.read_csv("/kaggle/input/weight-height/weight-height.csv")

# %%
df
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %%
df.describe()
# Out:
#              Height        Weight
# count  10000.000000  10000.000000
# mean      66.367560    161.440357
# std        3.847528     32.108439
# min       54.263133     64.700127
# 25%       63.505620    135.818051
# 50%       66.318070    161.212928
# 75%       69.174262    187.169525
# max       78.998742    269.989699

# %% [markdown]
# # Step 1: first plot histograms for height and weight parameters

# %%
# Histogram for Height

plt.hist(df['Height'], bins=15, rwidth=0.6)
plt.show()

# %%
# Histogram for Weight

plt.hist(df['Weight'], bins=15, rwidth=0.6)
plt.show()

# %% [markdown]
# # Step 2: Using IQR detect weight outliers and print them

# %%
# Calculate Q1 and Q3 

Q1 = df['Weight'].quantile(0.25)
Q3 = df['Weight'].quantile(0.75)

# %%
Q1, Q3
# Out:
# (135.8180513055015, 187.16952486868348)

# %%
# Calculate IQR

IQR = Q3 - Q1

# %%
IQR
# Out:
# 51.35147356318197

# %%
min_threshold = Q1 - 1.5*IQR
max_threshold = Q3 + 1.5*IQR

# %%
min_threshold, max_threshold
# Out:
# (58.79084096072856, 264.19673521345646)

# %%
# So the outliers are: 

df[(df['Weight'] < min_threshold) | (df['Weight'] > max_threshold)]
# Out:
#      Gender     Height      Weight
# 2014   Male  78.998742  269.989699

# %% [markdown]
# # Step 3: Using IQR, detect height outliers and print them

# %%
# Calculate Q1 and Q3 

Q1 = df['Height'].quantile(0.25)
Q3 = df['Height'].quantile(0.75)

# %%
Q1, Q3
# Out:
# (63.505620481218955, 69.1742617268347)

# %%
# Calculate IQR

IQR = Q3 - Q1

# %%
IQR
# Out:
# 5.668641245615746

# %%
min_threshold = Q1 - 1.5*IQR
max_threshold = Q3 + 1.5*IQR

# %%
min_threshold, max_threshold
# Out:
# (55.00265861279534, 77.67722359525831)

# %%
# So the outliers are: 

df[(df['Height'] < min_threshold) | (df['Height'] > max_threshold)]
# Out:
#       Gender     Height      Weight
# 994     Male  78.095867  255.690835
# 1317    Male  78.462053  227.342565
# 2014    Male  78.998742  269.989699
# 3285    Male  78.528210  253.889004
# 3757    Male  78.621374  245.733783
# 6624  Female  54.616858   71.393749
# 7294  Female  54.873728   78.606670
# 9285  Female  54.263133   64.700127
